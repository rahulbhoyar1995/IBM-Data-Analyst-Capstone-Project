# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Web Scraping Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Objectives

# %% [markdown]
# After completing this lab you will be able to:

# %% [markdown]
# * Download a webpage using requests module
# * Scrape all links from a web page
# * Scrape all image urls from a web page
# * Scrape data from html tables

# %% [markdown]
# ## Scrape www.ibm.com

# %% [markdown]
# Import the required modules and functions

# %%
from bs4 import BeautifulSoup # this module helps in web scrapping.
import requests  # this module helps us to download a web page

# %% [markdown]
# Download the contents of the web page

# %%
url = "http://www.ibm.com"

# %%
# get the contents of the webpage in text format and store in a variable called data
data  = requests.get(url).text

# %%
print(data)
# Out:
# <!DOCTYPE HTML>
# <html lang="en-us">
# <head>
#
#
#
#
#     <meta charset="UTF-8"/>
#     <meta name="languageCode" content="en"/>
#     <meta name="countryCode" content="us"/>
#     <meta name="searchTitle" content="IBM - United States"/>
#     <meta name="focusArea" content="No Contact Module"/>
#     <title>IBM - United States</title>
#     <link rel="icon" href="/content/dam/adobe-cms/default-images/favicon.svg"/>
#
#     <meta name="description" content="For more than a century, IBM has been a global technology innovator, leading advances in AI, automation and hybrid cloud solutions that help businesses grow."/>
#     <meta name="template" content="full-width-layout"/>
#     <meta name="viewport" content="width=device-width, initial-scale=1"/>
#     <meta name="robots" content="index, follow"/>
#
#     <link rel="canonical" href="https://www.ibm.com/"/>
#     <style id="anti-flicker-style">
#         :not(:defined) {
#           visibility: hidden;
#         }
#     </style>
#     <script type="text/javascript" id="anti-flicker-script">
#         (async () => {
#           await customElements.whenDefined('dds-masthead-container');
#           document.getElementById('anti-flicker-style').remove();
#           document.getElementById('anti-flicker-script').remove();
#         })()
#     </script>
#
#
#     <script type="text/javascript">
#         window.searchKey = {
#             templateName: 'full\u002Dwidth\u002Dlayout',
#             taxonomylist: '',
#             L0Tag: 'CMaaS Focus Areas,Topics,Brands,Industries,Geography,Compliance Entities,Products',
#         }
#     </script>
#
# <!--    <script>
#       (function(s,t,a,n){s[t]||(s[t]=a,n=s[a]=function(){n.q.push(arguments)},
#       n.q=[],n.v=2,n.l=1*new Date)})(window,"InstanaEumObject","ineum");
#       ineum('reportingUrl', 'https://eum-orange-saas.instana.io');
#       ineum('key', 'QSUr0uqUS0m37yyre8ntkQ');
#       ineum('trackSessions');
#     </script>
#     <script defer crossorigin="anonymous" src="https://eum.instana.io/eum.min.js"></script>-->
#
#
#         <link rel="alternate" hreflang="de-de" href="https://www.ibm.com/de-de"/>
#
#         <link rel="alternate" hreflang="en-us" href="https://www.ibm.com/"/>
#
#         <link rel="alternate" hreflang="en-ca" href="https://www.ibm.com/ca-en"/>
#
#         <link rel="alternate" hreflang="ko-kr" href="https://www.ibm.com/kr-ko"/>
#
#         <link rel="alternate" hreflang="pt-br" href="https://www.ibm.com/br-pt"/>
#
#         <link rel="alternate" hreflang="en-in" href="https://www.ibm.com/in-en"/>
#
#         <link rel="alternate" hreflang="es-es" href="https://www.ibm.com/es-es"/>
#
#         <link rel="alternate" hreflang="zh-cn" href="https://www.ibm.com/cn-zh"/>
#
#         <link rel="alternate" hreflang="es-mx" href="https://www.ibm.com/mx-es"/>
#
#         <link rel="alternate" hreflang="fr-ca" href="https://www.ibm.com/ca-fr"/>
#
#         <link rel="alternate" hreflang="it-it" href="https://www.ibm.com/it-it"/>
#
#         <link rel="alternate" hreflang="id-id" href="https://www.ibm.com/id-id"/>
#
#         <link rel="alternate" hreflang="en-au" href="https://www.ibm.com/au-en"/>
#
#         <link rel="alternate" hreflang="en-uk" href="https://www.ibm.com/uk-en"/>
#
#         <link rel="alternate" hreflang="fr-fr" href="https://www.ibm.com/fr-fr"/>
#
#         <link rel="alternate" hreflang="ja-jp" href="https://www.ibm.com/jp-ja"/>
#
#     <script type="text/javascript">
#         window.antiFlicker = {
#             active: true,
#             timeout: 3000
#         }
#     </script>
#     <script type="text/javascript">
#         var languageCode = document.getElementsByName('languageCode')[0].content;
#         var countryCode = document.getElementsByName('countryCode')[0].content;
#         var focusArea = document.getElementsByName('focusArea')[0].content;
#         /* Define digital data object based on _appInfo object */
#         window.digitalData = {
#             page: {
#                 category: {
#                     primaryCategory: '',
#                 },
#                 pageInfo: {
#                     language: languageCode + '-' + countryCode,
#                     ibm: {
#                         siteID: 'MarketingAEM',
#                         country: countryCode,
#                         messaging: {
#                             routing: {
#                                 focusArea: focusArea,
#                                 languageCode: languageCode,
#                                 regionCode: countryCode
#                             },
#                             translation: {
#                                 languageCode: languageCode,
#                                 regionCode: countryCode
#                             }
#                         },
#                         sections: 0,
#                         patterns: 0
#                     }
#                 }
#             }
#         };
#     </script>
#
#
#         <meta property="og:url" content="https://www.ibm.com/"/>
#
#         <meta property="og:type" content="website"/>
#
#         <meta property="og:title" content="IBM - United States"/>
#
#         <meta property="og:description" content="For more than a century, IBM has been a global technology innovator, leading advances in AI, automation and hybrid cloud solutions that help businesses grow."/>
#
#         <meta property="og:image" content="https://www.ibm.com/content/dam/connectedassets-adobe-cms/worldwide-content/pm/ul/g/f4/76/governance-native-1.jpg/_jcr_content/renditions/cq5dam.web.3840.3840.jpeg"/>
#
#
#
#
#     <script src="https://1.www.s81c.com/common/stats/ibm-common.js" type="text/javascript" async="async"></script>
#     <script src="https://s3.us.cloud-object-storage.appdomain.cloud/widget-registry/loader.js" type="application/javascript"></script>
#
#
#
# <link rel="stylesheet" href="/etc.clientlibs/adobe-cms/clientlibs/clientlib-idlStylesCarbon.min.ACSHASH6b7f7aca22f55d7ccef93668b20d1b11.css" type="text/css">
# <link rel="stylesheet" href="/etc.clientlibs/adobe-cms/clientlibs/clientlib-idlStyles.min.ACSHASH762826f2cec6438d8e48c6548d113a1d.css" type="text/css">
#
#
#
#
#     <link rel="stylesheet" href="https://1.www.s81c.com/common/carbon-for-ibm-dotcom/tag/v1/latest/plex.css"/>
#     <link rel="stylesheet" href="https://1.www.s81c.com/common/carbon/plex/sans.css"/>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# </head>
# <body class="content-page page basicpage publish" id="content-page-c8104b3589">
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div class="root container responsivegrid">
#
#
#
#
#     <div id="container-9225520bd9" class="cmp-container">
#
#         <div class="masthead">
#
#
#
#
#
#
#
#
# <dds-masthead-container data-endpoint="/common/carbon-for-ibm-dotcom/translations/masthead-footer/v2" auth-method="profile-api" has-contact="false"></dds-masthead-container>
#
#
#
#
# <script src="https://1.www.s81c.com/common/carbon-for-ibm-dotcom/tag/v2/alpha/masthead.min.js" type="module"></script>
#
#
#
#
# </div>
# <div class="leadspace-container container responsivegrid">
#
#
#
#
#     <div id="leadspace-container-1e918979ca" class="cmp-container">
#
#         <div class="leadspace-expanded leadspace">
# <section class="theme-white">
#     <dds-video-cta-container>
#         <caem-container-leadspace size="tall">
#
#
#
#                 <caem-heading slot="heading" type="h1" type-style="display-01" id="leadspaceSimpleTitle">
#
#
#
#   <dds-content-group-heading>
#
#
#
#
# <span class="enhanced-title">Put AI to work with watson<span class="enhanced-title-blue">x</span></span>
#
#
#
#
#
#   </dds-content-group-heading>
#
#
#
#
#
#
#
#
#
#                 </caem-heading>
#
#
#             <caem-paragraph size="lead-in" data-autoid="caem--paragraph">
#                 <p>
#
#
#
#
#       IBM’s next-generation AI and data platform brings together new generative AI capabilities
#
#
#
#
#
#
#
# </p>
#             </caem-paragraph>
#
#
#
#
#                 <caem-button-group slot="action">
#
#
#
#
#
#
#
#
#
#
#
#
#     <caem-button-cta href="https://dataplatform.cloud.ibm.com/registration/stepone?context=wx&lnk=hpUSls1" target="_blank" kind="primary" cta-type="local">
#         <span>Try for free</span>
#
#
#     </caem-button-cta>
#
#
#
#
#
#
#
#
#     <caem-button-cta href="https://www.ibm.com/products/watsonx-ai?lnk=hpUSls2" target="_blank" kind="tertiary" cta-type="local">
#         <span>Meet watsonx.ai</span>
#
#
#     </caem-button-cta>
#
#
#
#
#
#                 </caem-button-group>
#
#
#
#
#                 <caem-video-player-container aspect-ratio="4x3" slot="media" video-id="1_ixmv5wsn" caption-alignment="left" playing-mode="inline" thumbnail="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/s-migr/ul/g/75/75/watsonx-overview-leadspace-super-hybrid-ui-homepage.component.crop-1by1-xl.ts=1706190245228.png/content/adobe-cms/us/en/homepage/jcr:content/root/leadspace_container/leadspace_expanded_c"></caem-video-player-container>
#
#
#
#
#                     <dds-link-list slot="aside">
#                         <dds-link-list-heading role="heading" aria-level="4" slot="heading">
#
#
#
#
#
#       Latest news
#
#
#
#
#
#
#
#
#
#                         </dds-link-list-heading>
#
#
#
#
#
#
#         <caem-link-list-item cta-type="local" href="https://newsroom.ibm.com/2024-01-25-IBM-Unveils-AI-Stories-with-watsonx-to-Enhance-the-Digital-Fan-Experience-for-66th-Annual-GRAMMY-Awards-R?lnk=hpUSsl1" label="Meet AI Stories" target="_blank">
#
#
#
#
#
#
#
#             <p>See how watsonx is enhancing the fan experience at this year’s GRAMMYs</p>
#
#             <dds-card-cta-footer href="https://newsroom.ibm.com/2024-01-25-IBM-Unveils-AI-Stories-with-watsonx-to-Enhance-the-Digital-Fan-Experience-for-66th-Annual-GRAMMY-Awards-R?lnk=hpUSsl1" target="_blank" cta-type="local">
#
#             </dds-card-cta-footer>
#         </caem-link-list-item>
#
#
#
#
#
#
#
#
# <script type="module" src="https://1.www.s81c.com/common/carbon/carbon-for-aem/version/v0.9.2/link-list-item.min.js"></script>
#
#
#
#
#
#
#
#         <caem-link-list-item cta-type="local" href="https://newsroom.ibm.com/2024-01-24-IBM-RELEASES-FOURTH-QUARTER-RESULTS?lnk=hpUSsl2" label="Just announced" target="_blank">
#
#
#
#
#
#
#
#             <p>IBM 4Q 2023 Earnings Announcement </p>
#
#             <dds-card-cta-footer href="https://newsroom.ibm.com/2024-01-24-IBM-RELEASES-FOURTH-QUARTER-RESULTS?lnk=hpUSsl2" target="_blank" cta-type="local">
#
#             </dds-card-cta-footer>
#         </caem-link-list-item>
#
#
#
#
#
#
#
#
# <script type="module" src="https://1.www.s81c.com/common/carbon/carbon-for-aem/version/v0.9.2/link-list-item.min.js"></script>
#
#                 </dds-link-list>
#
#
#         </caem-container-leadspace>
# </dds-video-cta-container>
# </section>
# <script type="module" src="https://1.www.s81c.com/common/carbon/carbon-for-aem/version/v0.9.2/paragraph.min.js"></script>
# <script type="module" src="https://1.www.s81c.com/common/carbon/carbon-for-aem/version/v0.9.2/heading.min.js"></script>
# <script src="https://1.www.s81c.com/common/carbon/carbon-for-aem/version/v0.9.2/leadspace.min.js" type="module"></script></div>
#
#
#     </div>
#
# </div>
# <div class="table-of-contents container responsivegrid">
# <dds-table-of-contents data-cmp-is="table-of-contents" data-autoid="dds--table-of-contents" class="cmp-table-of-contents" stickyoffset="48" toc-layout="horizontal" toc-hide="hidden">
#
#
#     <div id="table-of-contents-b422012d4b" class="cmp-table-of-contents">
#
#         <div class="modular-container container responsivegrid">
#
#
#
#
#     <div id="modular-container-5d1eac4ca1" class="cmp-container">
#
#         <div class="standalone-title enhanced-title text">
#
#
#
# <caem-heading type="h5">Recommended for you<br /></caem-heading>
#
#
#
# <script type="module" src="https://1.www.s81c.com/common/carbon/carbon-for-aem/version/v0.9.2/heading.min.js"></script></div>
#
#
#     </div>
#
# </div>
# <div class="tile-group-container container responsivegrid">
#   <div class="bx--col">
#     <caem-tile-group>
#
#
#
#
#     <caem-tile label="Try watsonx" cta-type="local" href="https://www.ibm.com/info/generative-ai?lnk=hpUSrc1" target="_blank">
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <dds-image id="image--795210649" alt="Fingers and hands pointing or gesturing to widgets or moving through a process" slot="image" default-src="/content/dam/connectedassets-adobe-cms/worldwide-content/pm/ul/g/f4/76/governance-native-1.component.tile-card-xl.ts=1706190245883.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card/image">
#
#
#
#
#     <dds-image-item media="(min-width: 1312px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/pm/ul/g/f4/76/governance-native-1.component.tile-card-xl-retina.ts=1706190245883.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1312px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/pm/ul/g/f4/76/governance-native-1.component.tile-card-xl.ts=1706190245883.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1056px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/pm/ul/g/f4/76/governance-native-1.component.tile-card-l-retina.ts=1706190245883.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1056px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/pm/ul/g/f4/76/governance-native-1.component.tile-card-l.ts=1706190245883.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card/image"></dds-image-item>
#     <dds-image-item media="(min-width: 672px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/pm/ul/g/f4/76/governance-native-1.component.tile-card-m-retina.ts=1706190245883.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card/image"></dds-image-item>
#     <dds-image-item media="(min-width: 672px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/pm/ul/g/f4/76/governance-native-1.component.tile-card-m.ts=1706190245883.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card/image"></dds-image-item>
#     <dds-image-item media="(min-width: 481px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/pm/ul/g/f4/76/governance-native-1.component.tile-card-s-retina.ts=1706190245883.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card/image"></dds-image-item>
#     <dds-image-item media="(min-width: 481px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/pm/ul/g/f4/76/governance-native-1.component.tile-card-s.ts=1706190245883.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card/image"></dds-image-item>
#     <dds-image-item media="(max-width: 480px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/pm/ul/g/f4/76/governance-native-1.component.tile-card-xs-retina.ts=1706190245883.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card/image"></dds-image-item>
#     <dds-image-item media="(max-width: 480px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/pm/ul/g/f4/76/governance-native-1.component.tile-card-xs.ts=1706190245883.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card/image"></dds-image-item>
#
#
#
#
#         </dds-image>
#
#
#
#
#
#
#
#
#
#
#         Transform your business with generative AI
#
#
#
#
#
#
#
#         <p slot="cta">
#
#         </p>
#
#     </caem-tile>
#
#     <div class="caem-card-svg-source" hidden>
#         <svg xmlns="http://www.w3.org/2000/svg" id="accelerated-computing" viewBox="0 0 32 32"><path d="M19,29.36c-3.401,0-6.596-1.506-8.764-4.131l0.556-0.459c2.03,2.459,5.022,3.869,8.208,3.869 c5.867,0,10.64-4.772,10.64-10.64c0-5.867-4.772-10.64-10.64-10.64c-3.186,0-6.177,1.411-8.208,3.87l-0.555-0.459 c2.091-2.532,5.137-4.022,8.403-4.125V5.36H16c-0.199,0-0.36-0.161-0.36-0.36V3c0-0.199,0.161-0.36,0.36-0.36h6 c0.199,0,0.36,0.161,0.36,0.36v2c0,0.199-0.161,0.36-0.36,0.36h-2.64v1.286c6.098,0.191,11,5.211,11,11.354 C30.36,24.264,25.264,29.36,19,29.36z M16.36,4.64h5.28V3.36h-5.28V4.64z M14,23.36H4v-0.72h10V23.36z M12,18.36H2v-0.72h10V18.36z M19.179,18.312l-0.357-0.625l7-4l0.357,0.625L19.179,18.312z M14,13.36H4v-0.72h10V13.36z"/></svg>
#     </div>
#
#
#
#
#
# <script src="https://1.www.s81c.com/common/carbon/carbon-for-aem/version/v0.9.2/tile.min.js" type="module"></script>
#
#
#
#
#
#     <caem-tile label="Customer service" cta-type="local" href="https://www.ibm.com/consulting/customer-service?lnk=hpUSrc2" target="_self">
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <dds-image id="image-1647910644" alt="Customer service agent with open laptop, analytics, documents, chat bubbles and conversation" slot="image" default-src="/content/dam/connectedassets-adobe-cms/worldwide-content/cdp/cf/ul/g/64/22/talk-to-human.component.tile-card-xl.ts=1706190246028.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_2105644765/image">
#
#
#
#
#     <dds-image-item media="(min-width: 1312px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/cdp/cf/ul/g/64/22/talk-to-human.component.tile-card-xl-retina.ts=1706190246028.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_2105644765/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1312px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/cdp/cf/ul/g/64/22/talk-to-human.component.tile-card-xl.ts=1706190246028.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_2105644765/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1056px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/cdp/cf/ul/g/64/22/talk-to-human.component.tile-card-l-retina.ts=1706190246028.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_2105644765/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1056px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/cdp/cf/ul/g/64/22/talk-to-human.component.tile-card-l.ts=1706190246028.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_2105644765/image"></dds-image-item>
#     <dds-image-item media="(min-width: 672px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/cdp/cf/ul/g/64/22/talk-to-human.component.tile-card-m-retina.ts=1706190246028.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_2105644765/image"></dds-image-item>
#     <dds-image-item media="(min-width: 672px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/cdp/cf/ul/g/64/22/talk-to-human.component.tile-card-m.ts=1706190246028.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_2105644765/image"></dds-image-item>
#     <dds-image-item media="(min-width: 481px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/cdp/cf/ul/g/64/22/talk-to-human.component.tile-card-s-retina.ts=1706190246028.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_2105644765/image"></dds-image-item>
#     <dds-image-item media="(min-width: 481px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/cdp/cf/ul/g/64/22/talk-to-human.component.tile-card-s.ts=1706190246028.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_2105644765/image"></dds-image-item>
#     <dds-image-item media="(max-width: 480px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/cdp/cf/ul/g/64/22/talk-to-human.component.tile-card-xs-retina.ts=1706190246028.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_2105644765/image"></dds-image-item>
#     <dds-image-item media="(max-width: 480px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/cdp/cf/ul/g/64/22/talk-to-human.component.tile-card-xs.ts=1706190246028.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_2105644765/image"></dds-image-item>
#
#
#
#
#         </dds-image>
#
#
#
#
#
#
#
#
#
#
#         Resolve issues in real time with conversational AI
#
#
#
#
#
#
#
#         <p slot="cta">
#
#         </p>
#
#     </caem-tile>
#
#     <div class="caem-card-svg-source" hidden>
#         <svg xmlns="http://www.w3.org/2000/svg" id="accelerated-computing" viewBox="0 0 32 32"><path d="M19,29.36c-3.401,0-6.596-1.506-8.764-4.131l0.556-0.459c2.03,2.459,5.022,3.869,8.208,3.869 c5.867,0,10.64-4.772,10.64-10.64c0-5.867-4.772-10.64-10.64-10.64c-3.186,0-6.177,1.411-8.208,3.87l-0.555-0.459 c2.091-2.532,5.137-4.022,8.403-4.125V5.36H16c-0.199,0-0.36-0.161-0.36-0.36V3c0-0.199,0.161-0.36,0.36-0.36h6 c0.199,0,0.36,0.161,0.36,0.36v2c0,0.199-0.161,0.36-0.36,0.36h-2.64v1.286c6.098,0.191,11,5.211,11,11.354 C30.36,24.264,25.264,29.36,19,29.36z M16.36,4.64h5.28V3.36h-5.28V4.64z M14,23.36H4v-0.72h10V23.36z M12,18.36H2v-0.72h10V18.36z M19.179,18.312l-0.357-0.625l7-4l0.357,0.625L19.179,18.312z M14,13.36H4v-0.72h10V13.36z"/></svg>
#     </div>
#
#
#
#
#
# <script src="https://1.www.s81c.com/common/carbon/carbon-for-aem/version/v0.9.2/tile.min.js" type="module"></script>
#
#
#
#     <caem-tile label="Talent management" cta-type="local" href="https://www.ibm.com/consulting/talent-management?lnk=hpUSrc3" target="_self">
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <dds-image id="image--709325514" alt="HR person surrounded by icons" slot="image" default-src="/content/dam/connectedassets-adobe-cms/worldwide-content/cdp/cf/ul/g/a7/31/hr-service-self-support.component.tile-card-xl.ts=1706190246235.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_392377621/image">
#
#
#
#
#     <dds-image-item media="(min-width: 1312px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/cdp/cf/ul/g/a7/31/hr-service-self-support.component.tile-card-xl-retina.ts=1706190246235.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_392377621/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1312px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/cdp/cf/ul/g/a7/31/hr-service-self-support.component.tile-card-xl.ts=1706190246235.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_392377621/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1056px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/cdp/cf/ul/g/a7/31/hr-service-self-support.component.tile-card-l-retina.ts=1706190246235.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_392377621/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1056px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/cdp/cf/ul/g/a7/31/hr-service-self-support.component.tile-card-l.ts=1706190246235.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_392377621/image"></dds-image-item>
#     <dds-image-item media="(min-width: 672px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/cdp/cf/ul/g/a7/31/hr-service-self-support.component.tile-card-m-retina.ts=1706190246235.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_392377621/image"></dds-image-item>
#     <dds-image-item media="(min-width: 672px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/cdp/cf/ul/g/a7/31/hr-service-self-support.component.tile-card-m.ts=1706190246235.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_392377621/image"></dds-image-item>
#     <dds-image-item media="(min-width: 481px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/cdp/cf/ul/g/a7/31/hr-service-self-support.component.tile-card-s-retina.ts=1706190246235.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_392377621/image"></dds-image-item>
#     <dds-image-item media="(min-width: 481px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/cdp/cf/ul/g/a7/31/hr-service-self-support.component.tile-card-s.ts=1706190246235.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_392377621/image"></dds-image-item>
#     <dds-image-item media="(max-width: 480px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/cdp/cf/ul/g/a7/31/hr-service-self-support.component.tile-card-xs-retina.ts=1706190246235.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_392377621/image"></dds-image-item>
#     <dds-image-item media="(max-width: 480px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/cdp/cf/ul/g/a7/31/hr-service-self-support.component.tile-card-xs.ts=1706190246235.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_392377621/image"></dds-image-item>
#
#
#
#
#         </dds-image>
#
#
#
#
#
#
#
#
#
#
#         Reimagine HR with AI at the core
#
#
#
#
#
#
#
#         <p slot="cta">
#
#         </p>
#
#     </caem-tile>
#
#     <div class="caem-card-svg-source" hidden>
#         <svg xmlns="http://www.w3.org/2000/svg" id="accelerated-computing" viewBox="0 0 32 32"><path d="M19,29.36c-3.401,0-6.596-1.506-8.764-4.131l0.556-0.459c2.03,2.459,5.022,3.869,8.208,3.869 c5.867,0,10.64-4.772,10.64-10.64c0-5.867-4.772-10.64-10.64-10.64c-3.186,0-6.177,1.411-8.208,3.87l-0.555-0.459 c2.091-2.532,5.137-4.022,8.403-4.125V5.36H16c-0.199,0-0.36-0.161-0.36-0.36V3c0-0.199,0.161-0.36,0.36-0.36h6 c0.199,0,0.36,0.161,0.36,0.36v2c0,0.199-0.161,0.36-0.36,0.36h-2.64v1.286c6.098,0.191,11,5.211,11,11.354 C30.36,24.264,25.264,29.36,19,29.36z M16.36,4.64h5.28V3.36h-5.28V4.64z M14,23.36H4v-0.72h10V23.36z M12,18.36H2v-0.72h10V18.36z M19.179,18.312l-0.357-0.625l7-4l0.357,0.625L19.179,18.312z M14,13.36H4v-0.72h10V13.36z"/></svg>
#     </div>
#
#
#
#
#
# <script src="https://1.www.s81c.com/common/carbon/carbon-for-aem/version/v0.9.2/tile.min.js" type="module"></script>
#
#
#
#     <caem-tile label="Modernize applications" cta-type="local" href="https://www.ibm.com/consulting/application-modernization?lnk=hpUSrc4" target="_blank">
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <dds-image id="image-1385655759" alt="Snippets of an application using watsonx™ Code Assistant" slot="image" default-src="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/s-migr/ul/g/79/6e/watsonx-code-assistant-284x284-email.component.tile-card-xl.ts=1706190246408.png/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_1699798462/image">
#
#
#
#
#     <dds-image-item media="(min-width: 1312px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/s-migr/ul/g/79/6e/watsonx-code-assistant-284x284-email.component.tile-card-xl-retina.ts=1706190246408.png/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_1699798462/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1312px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/s-migr/ul/g/79/6e/watsonx-code-assistant-284x284-email.component.tile-card-xl.ts=1706190246408.png/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_1699798462/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1056px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/s-migr/ul/g/79/6e/watsonx-code-assistant-284x284-email.component.tile-card-l-retina.ts=1706190246408.png/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_1699798462/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1056px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/s-migr/ul/g/79/6e/watsonx-code-assistant-284x284-email.component.tile-card-l.ts=1706190246408.png/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_1699798462/image"></dds-image-item>
#     <dds-image-item media="(min-width: 672px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/s-migr/ul/g/79/6e/watsonx-code-assistant-284x284-email.component.tile-card-m-retina.ts=1706190246408.png/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_1699798462/image"></dds-image-item>
#     <dds-image-item media="(min-width: 672px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/s-migr/ul/g/79/6e/watsonx-code-assistant-284x284-email.component.tile-card-m.ts=1706190246408.png/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_1699798462/image"></dds-image-item>
#     <dds-image-item media="(min-width: 481px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/s-migr/ul/g/79/6e/watsonx-code-assistant-284x284-email.component.tile-card-s-retina.ts=1706190246408.png/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_1699798462/image"></dds-image-item>
#     <dds-image-item media="(min-width: 481px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/s-migr/ul/g/79/6e/watsonx-code-assistant-284x284-email.component.tile-card-s.ts=1706190246408.png/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_1699798462/image"></dds-image-item>
#     <dds-image-item media="(max-width: 480px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/s-migr/ul/g/79/6e/watsonx-code-assistant-284x284-email.component.tile-card-xs-retina.ts=1706190246408.png/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_1699798462/image"></dds-image-item>
#     <dds-image-item media="(max-width: 480px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/s-migr/ul/g/79/6e/watsonx-code-assistant-284x284-email.component.tile-card-xs.ts=1706190246408.png/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_1699798462/image"></dds-image-item>
#
#
#
#
#         </dds-image>
#
#
#
#
#
#
#
#
#
#
#         Use AI upgrades to optimize performance
#
#
#
#
#
#
#
#         <p slot="cta">
#
#         </p>
#
#     </caem-tile>
#
#     <div class="caem-card-svg-source" hidden>
#         <svg xmlns="http://www.w3.org/2000/svg" id="accelerated-computing" viewBox="0 0 32 32"><path d="M19,29.36c-3.401,0-6.596-1.506-8.764-4.131l0.556-0.459c2.03,2.459,5.022,3.869,8.208,3.869 c5.867,0,10.64-4.772,10.64-10.64c0-5.867-4.772-10.64-10.64-10.64c-3.186,0-6.177,1.411-8.208,3.87l-0.555-0.459 c2.091-2.532,5.137-4.022,8.403-4.125V5.36H16c-0.199,0-0.36-0.161-0.36-0.36V3c0-0.199,0.161-0.36,0.36-0.36h6 c0.199,0,0.36,0.161,0.36,0.36v2c0,0.199-0.161,0.36-0.36,0.36h-2.64v1.286c6.098,0.191,11,5.211,11,11.354 C30.36,24.264,25.264,29.36,19,29.36z M16.36,4.64h5.28V3.36h-5.28V4.64z M14,23.36H4v-0.72h10V23.36z M12,18.36H2v-0.72h10V18.36z M19.179,18.312l-0.357-0.625l7-4l0.357,0.625L19.179,18.312z M14,13.36H4v-0.72h10V13.36z"/></svg>
#     </div>
#
#
#
#
#
# <script src="https://1.www.s81c.com/common/carbon/carbon-for-aem/version/v0.9.2/tile.min.js" type="module"></script>
#
#
#
#
#     </caem-tile-group>
#   </div>
#
#
# <script type="module" src="https://1.www.s81c.com/common/carbon/carbon-for-aem/version/v0.9.2/tile.min.js"></script></div>
# <div class="intro-section"><div class="bx--col">
#     <caem-intro-section>
#
#         <caem-heading slot="heading" type="h2" type-style="expressive-heading-05" data-autoid="caem-heading">
#
#
#
#
#
#     Browse our technology
#
#
#
#
#
#
#
#
#
#             </caem-heading>
#
#         <caem-paragraph size="lead-in" data-autoid="caem--paragraph">
#             <div class="cms-richtext" id="rich-text-c26afb5940" data-dynamic-inner-content="description">
#     <p>From our flagship products for enterprise <a href="https://www.ibm.com/cloud?lnk=hpUSbt1">hybrid cloud infrastructure</a> to next-generation AI, security and storage solutions, find the answer to your business challenge.</p>
#
#
#
#
#
#
# </div>
#         </caem-paragraph>
#
#
#             <dds-link-list type="vertical">
#
#
#
#
#
#         <dds-video-cta-container>
#             <dds-link-list-item-cta cta-type="local" href="https://www.ibm.com/products?lnk=hpUSbt2" icon-placement="right" role="listitem" target="_self">
#                 View all products
#
#             </dds-link-list-item-cta>
#         </dds-video-cta-container>
#
#
#
#
#
#
#
#
#
#
#
#
#         <dds-video-cta-container>
#             <dds-link-list-item-cta cta-type="local" href="https://www.ibm.com/products/offers-and-discounts?lnk=hpUSbt3" icon-placement="right" role="listitem" target="_self">
#                 Shop special offers and discounts
#
#             </dds-link-list-item-cta>
#         </dds-video-cta-container>
#
#
#
#
#
#
#
#             </dds-link-list>
#
#
#
#
#     </caem-intro-section>
# </div>
# <script type="module" src="https://1.www.s81c.com/common/carbon/carbon-for-aem/version/v0.9.2/paragraph.min.js"></script>
# <script type="module" src="https://1.www.s81c.com/common/carbon/carbon-for-aem/version/v0.9.2/heading.min.js"></script>
# <script type="module" src="https://1.www.s81c.com/common/carbon/carbon-for-aem/version/v0.9.2/intro-section.min.js"></script>
# <script type="module" src="https://1.www.s81c.com/common/carbon/carbon-for-aem/version/v0.9.2/brand-cta-section.min.js"></script>
# </div>
# <div class="card-group-pictogram-full-width card-group-pictogram">
#     <div class="bx--content-block">
#
#
#
#
#
#                 <caem-card-group grid-mode="border" cards-per-row="4" data-autoid="dds--card-group" style="--dds--card-group--cards-in-row:4">
#
#
#
#
#
#
#
#
#
#
#
#                 <caem-card color-scheme cta-type="local" data-autoid="caem--card" href="https://www.ibm.com/artificial-intelligence?lnk=prodC" target="_self" pictogram-placement="top" size>
#                     <caem-card-heading aria-level="3" data-autoid="caem--card-heading" role="heading" slot="heading">
#
#                         AI &amp; machine learning</caem-card-heading>
#                     <svg slot="pictogram" class="bx--card__pictogram" data-autoid="caem--card__pictogram" focusable="false" height="48" width="48" role="img">
#                         <use href="#ai"></use>
#                     </svg>
#                     <p>Use IBM Watsonx’s AI or build your own machine learning models</p>
#                     <caem-card-cta-footer color-scheme target="_self" cta-type="local" data-autoid="caem--card-cta-footer" href="https://www.ibm.com/artificial-intelligence?lnk=prodC" icon-placement="right" parent-href="https://www.ibm.com/artificial-intelligence?lnk=prodC" slot="footer">
#
#                     </caem-card-cta-footer>
#                     <div class="caem-card-svg-source">
#                         <svg xmlns="http://www.w3.org/2000/svg" id="ai" viewBox="0 0 32 32"><path d="M16.195,31.36c-6.421,0-12.169-4.007-14.399-10.002 C1.051,21.408,0.373,20.771,0.372,20c0-0.75,0.61-1.36,1.36-1.36s1.36,0.61,1.36,1.36c0,0.474-0.243,0.892-0.611,1.135 c2.133,5.698,7.604,9.505,13.714,9.505c6.446,0,11.919-4.301,13.773-10.22c-1.448,2.06-3.877,3.44-6.565,3.44 c-3.822,0-7.066-2.785-7.664-6.525C15.113,17.212,14.64,16.661,14.64,16c0-0.584,0.37-1.083,0.888-1.275 c-0.608-3.421-3.615-5.962-7.125-5.962c-3.947,0-7.04,3.176-7.042,7.231c0,0.002,0,0.004,0,0.006H0.64c0-0.002,0-0.004,0-0.007 C0.644,7.526,7.445,0.64,15.805,0.64c6.42,0,12.168,4.006,14.399,10.001c0.777-0.034,1.425,0.587,1.425,1.358 c0,0.75-0.61,1.36-1.36,1.36s-1.36-0.61-1.36-1.36c0-0.473,0.243-0.891,0.611-1.135C27.387,5.166,21.916,1.36,15.805,1.36 c-6.319,0-11.704,4.134-13.659,9.873c1.402-1.949,3.662-3.19,6.256-3.19c3.881,0,7.204,2.826,7.846,6.62 C16.88,14.779,17.36,15.335,17.36,16c0,0.589-0.376,1.092-0.901,1.28c0.567,3.363,3.496,5.859,6.943,5.859 c3.857,0,7.127-3.118,7.235-6.851c0.001-0.096,0.002-0.192,0.002-0.289h0.721c0,0.033,0,0.065-0.001,0.098h0.001 c0,0.069-0.001,0.138-0.003,0.207C31.196,24.634,24.456,31.36,16.195,31.36z M1.732,19.36c-0.353,0-0.64,0.287-0.64,0.64 s0.287,0.64,0.64,0.64s0.64-0.287,0.64-0.64S2.085,19.36,1.732,19.36z M16,15.36c-0.353,0-0.64,0.287-0.64,0.64 s0.287,0.64,0.64,0.64s0.64-0.287,0.64-0.64S16.353,15.36,16,15.36z M30.269,11.36c-0.353,0-0.64,0.287-0.64,0.64 s0.287,0.64,0.64,0.64s0.64-0.287,0.64-0.64S30.621,11.36,30.269,11.36z"/></svg>
#                     </div>
#                 </caem-card>
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 <caem-card color-scheme cta-type="local" data-autoid="caem--card" href="https://www.ibm.com/analytics?lnk=ProdC" target="_self" pictogram-placement="top" size>
#                     <caem-card-heading aria-level="3" data-autoid="caem--card-heading" role="heading" slot="heading">
#
#                         Analytics</caem-card-heading>
#                     <svg slot="pictogram" class="bx--card__pictogram" data-autoid="caem--card__pictogram" focusable="false" height="48" width="48" role="img">
#                         <use href="#predictive-analytics"></use>
#                     </svg>
#                     <p>Aggregate and analyze large datasets</p>
#                     <caem-card-cta-footer color-scheme target="_self" cta-type="local" data-autoid="caem--card-cta-footer" href="https://www.ibm.com/analytics?lnk=ProdC" icon-placement="right" parent-href="https://www.ibm.com/analytics?lnk=ProdC" slot="footer">
#
#                     </caem-card-cta-footer>
#                     <div class="caem-card-svg-source">
#                         <svg xmlns="http://www.w3.org/2000/svg" id="predictive-analytics" viewBox="0 0 32 32"><path d="M31,31.36H1c-0.199,0-0.36-0.161-0.36-0.36 V1h0.72v29.64h4.28v-7.328c-0.576-0.158-1-0.687-1-1.312c0-0.75,0.61-1.36,1.36-1.36c0.364,0,0.694,0.144,0.938,0.377l3.702-2.221 v-8.484c-0.576-0.158-1-0.686-1-1.312c0-0.75,0.61-1.36,1.36-1.36S12.36,8.25,12.36,9c0,0.625-0.424,1.153-1,1.312v8.053l3.33-1.998 c-0.032-0.116-0.05-0.239-0.05-0.366c0-0.75,0.61-1.36,1.36-1.36c0.364,0,0.695,0.144,0.939,0.377l3.701-2.221V6.312 c-0.575-0.158-1-0.686-1-1.312c0-0.75,0.61-1.36,1.36-1.36S22.36,4.25,22.36,5c0,0.625-0.425,1.153-1,1.312v6.053l3.33-1.998 c-0.033-0.117-0.05-0.24-0.05-0.367c0-0.75,0.61-1.36,1.36-1.36s1.36,0.61,1.36,1.36c0,0.625-0.425,1.153-1,1.312V30.64H31V31.36z M21.36,30.64h4.279V11.312c-0.22-0.061-0.418-0.175-0.578-0.328l-3.701,2.221V30.64z M16.36,30.64h4.28V13.636l-3.33,1.998 c0.033,0.116,0.05,0.239,0.05,0.366c0,0.625-0.425,1.153-1,1.312V30.64z M11.36,30.64h4.28V17.312 c-0.22-0.061-0.418-0.175-0.579-0.328l-3.702,2.221V30.64H11.36z M6.36,30.64h4.28V19.636l-3.33,1.998 C7.343,21.75,7.36,21.873,7.36,22c0,0.625-0.424,1.153-1,1.312V30.64z M6,21.36c-0.353,0-0.64,0.287-0.64,0.64S5.647,22.64,6,22.64 S6.64,22.353,6.64,22S6.353,21.36,6,21.36z M16,15.36c-0.353,0-0.64,0.287-0.64,0.64s0.287,0.64,0.64,0.64s0.64-0.287,0.64-0.64 S16.353,15.36,16,15.36z M26,9.36c-0.353,0-0.64,0.287-0.64,0.64s0.287,0.64,0.64,0.64s0.64-0.287,0.64-0.64S26.353,9.36,26,9.36z M11,8.36c-0.353,0-0.64,0.287-0.64,0.64S10.647,9.64,11,9.64S11.64,9.353,11.64,9S11.353,8.36,11,8.36z M21,4.36 c-0.353,0-0.64,0.287-0.64,0.64S20.647,5.64,21,5.64S21.64,5.353,21.64,5S21.353,4.36,21,4.36z"/></svg>
#                     </div>
#                 </caem-card>
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 <caem-card color-scheme cta-type="local" data-autoid="caem--card" href="https://www.ibm.com/servers?lnk=ProdC" target="_self" pictogram-placement="top" size>
#                     <caem-card-heading aria-level="3" data-autoid="caem--card-heading" role="heading" slot="heading">
#
#                         Compute &amp; servers</caem-card-heading>
#                     <svg slot="pictogram" class="bx--card__pictogram" data-autoid="caem--card__pictogram" focusable="false" height="48" width="48" role="img">
#                         <use href="#storage--product"></use>
#                     </svg>
#                     <p>Run workloads on hybrid cloud infrastructure</p>
#                     <caem-card-cta-footer color-scheme target="_self" cta-type="local" data-autoid="caem--card-cta-footer" href="https://www.ibm.com/servers?lnk=ProdC" icon-placement="right" parent-href="https://www.ibm.com/servers?lnk=ProdC" slot="footer">
#
#                     </caem-card-cta-footer>
#                     <div class="caem-card-svg-source">
#                         <svg xmlns="http://www.w3.org/2000/svg" id="storage--product" viewBox="0 0 32 32"><path d="M30,31.36H8c-0.199,0-0.36-0.161-0.36-0.36v-5c0-0.199,0.161-0.36,0.36-0.36h22 c0.199,0,0.36,0.161,0.36,0.36v5C30.36,31.199,30.199,31.36,30,31.36z M8.36,30.64h21.28v-4.28H8.36V30.64z M6,31.36H2 c-0.199,0-0.36-0.161-0.36-0.36V1c0-0.199,0.161-0.36,0.36-0.36h11c0.199,0,0.36,0.161,0.36,0.36v9h-0.72V1.36H2.36v29.28H6V31.36z M28.36,30h-0.72v-2h0.721L28.36,30L28.36,30z M26.36,30h-0.72v-2h0.721L26.36,30L26.36,30z M24.36,30h-0.72v-2h0.721L24.36,30 L24.36,30z M22.36,30h-0.72v-2h0.721L22.36,30L22.36,30z M30,24.36H8c-0.199,0-0.36-0.161-0.36-0.36v-5 c0-0.199,0.161-0.36,0.36-0.36h22c0.199,0,0.36,0.161,0.36,0.36v5C30.36,24.199,30.199,24.36,30,24.36z M8.36,23.64h21.28v-4.28 H8.36V23.64z M28.36,23h-0.72v-2h0.721L28.36,23L28.36,23z M26.36,23h-0.72v-2h0.721L26.36,23L26.36,23z M24.36,23h-0.72v-2h0.721 L24.36,23L24.36,23z M22.36,23h-0.72v-2h0.721L22.36,23L22.36,23z M30,17.36H8c-0.199,0-0.36-0.161-0.36-0.36v-5 c0-0.199,0.161-0.36,0.36-0.36h22c0.199,0,0.36,0.161,0.36,0.36v5C30.36,17.199,30.199,17.36,30,17.36z M8.36,16.64h21.28v-4.28 H8.36V16.64z M28.36,16h-0.72v-2h0.721L28.36,16L28.36,16z M26.36,16h-0.72v-2h0.721L26.36,16L26.36,16z M24.36,16h-0.72v-2h0.721 L24.36,16L24.36,16z M22.36,16h-0.72v-2h0.721L22.36,16L22.36,16z M6,4.36H4V3.64h2V4.36z"/></svg>
#                     </div>
#                 </caem-card>
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 <caem-card color-scheme cta-type="local" data-autoid="caem--card" href="https://www.ibm.com/database?lnk=ProdC" target="_self" pictogram-placement="top" size>
#                     <caem-card-heading aria-level="3" data-autoid="caem--card-heading" role="heading" slot="heading">
#
#                         Databases</caem-card-heading>
#                     <svg slot="pictogram" class="bx--card__pictogram" data-autoid="caem--card__pictogram" focusable="false" height="48" width="48" role="img">
#                         <use href="#hard--drive--network"></use>
#                     </svg>
#                     <p>Store, query and analyze structured data</p>
#                     <caem-card-cta-footer color-scheme target="_self" cta-type="local" data-autoid="caem--card-cta-footer" href="https://www.ibm.com/database?lnk=ProdC" icon-placement="right" parent-href="https://www.ibm.com/database?lnk=ProdC" slot="footer">
#
#                     </caem-card-cta-footer>
#                     <div class="caem-card-svg-source">
#                         <svg xmlns="http://www.w3.org/2000/svg" id="hard--drive--network" viewBox="0 0 32 32"><path d="M20,6c-0.552,0-1-0.448-1-1s0.448-1,1-1s1,0.448,1,1S20.552,6,20,6z M21,16 c0-0.552-0.448-1-1-1s-1,0.448-1,1s0.448,1,1,1S21,16.552,21,16z M21,27c0-0.552-0.448-1-1-1s-1,0.448-1,1s0.448,1,1,1 S21,27.552,21,27z M24,31.36H1c-0.199,0-0.36-0.161-0.36-0.36v-8c0-0.199,0.161-0.36,0.36-0.36h23c0.199,0,0.36,0.161,0.36,0.36v8 C24.36,31.199,24.199,31.36,24,31.36z M1.36,30.64h22.28v-7.28H1.36V30.64z M31,27.36h-5v-0.72h4.64V16.36H26v-0.72h4.64V5.36H26 V4.64h5c0.199,0,0.36,0.161,0.36,0.36v22C31.36,27.199,31.199,27.36,31,27.36z M24,20.36H1c-0.199,0-0.36-0.161-0.36-0.36v-8 c0-0.199,0.161-0.36,0.36-0.36h23c0.199,0,0.36,0.161,0.36,0.36v8C24.36,20.199,24.199,20.36,24,20.36z M1.36,19.64h22.28v-7.28 H1.36V19.64z M24,9.36H1C0.801,9.36,0.64,9.199,0.64,9V1c0-0.199,0.161-0.36,0.36-0.36h23c0.199,0,0.36,0.161,0.36,0.36v8 C24.36,9.199,24.199,9.36,24,9.36z M1.36,8.64h22.28V1.36H1.36V8.64z"/></svg>
#                     </div>
#                 </caem-card>
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
#     <dds-image-item media="(min-width: 1056px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/ibs/ul/g/00/00/0100129_Oppermann_PE.component.card-l.ts=1706190247994.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1430209788/image"></dds-image-item>
#     <dds-image-item media="(min-width: 672px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/ibs/ul/g/00/00/0100129_Oppermann_PE.component.card-m-retina.ts=1706190247994.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1430209788/image"></dds-image-item>
#     <dds-image-item media="(min-width: 672px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/ibs/ul/g/00/00/0100129_Oppermann_PE.component.card-m.ts=1706190247994.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1430209788/image"></dds-image-item>
#     <dds-image-item media="(min-width: 481px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/ibs/ul/g/00/00/0100129_Oppermann_PE.component.card-s-retina.ts=1706190247994.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1430209788/image"></dds-image-item>
#     <dds-image-item media="(min-width: 481px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/ibs/ul/g/00/00/0100129_Oppermann_PE.component.card-s.ts=1706190247994.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1430209788/image"></dds-image-item>
#     <dds-image-item media="(max-width: 480px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/ibs/ul/g/00/00/0100129_Oppermann_PE.component.card-xs-retina.ts=1706190247994.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1430209788/image"></dds-image-item>
#     <dds-image-item media="(max-width: 480px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/ibs/ul/g/00/00/0100129_Oppermann_PE.component.card-xs.ts=1706190247994.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1430209788/image"></dds-image-item>
#
#
#
#
#         </dds-image>
#
#
#
#
#
#
#
#
#         <dds-card-eyebrow slot="eyebrow" aria-hidden="true" class="bx--card__eyebrow">
#             Careers at IBM
#         </dds-card-eyebrow>
#         <dds-card-heading role="heading" aria-level="3" slot="heading" class="bx--card__heading">
#             From safer food supply to ethical AI, tackle the world&#39;s toughest problems
#         </dds-card-heading>
#
#         <dds-card-cta-footer icon-placement="right" cta-type="local" href="https://www.ibm.com/careers?lnk=hpUSap" slot="footer" aria-hidden="true" target="_self" class="bx--card__footer-icon-size">
#
#
#
#
#
#
#
#         </dds-card-cta-footer>
#     </dds-card-group-item>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <dds-card-group-item href="https://research.ibm.com/?lnk=hpUSAp" target="_self" pictogram-placement="top" cta-type="local">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <dds-image id="image--1532602258" alt="A large quantum server at IBM Research " slot="image" default-src="/content/dam/connectedassets-adobe-cms/worldwide-content/other/ul/cms/0c/98/ibm-quantum-system-one.component.card-xl.ts=1706190248046.png/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card/image">
#
#
#
#
#     <dds-image-item media="(min-width: 1312px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/other/ul/cms/0c/98/ibm-quantum-system-one.component.card-xl-retina.ts=1706190248046.png/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1312px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/other/ul/cms/0c/98/ibm-quantum-system-one.component.card-xl.ts=1706190248046.png/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1056px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/other/ul/cms/0c/98/ibm-quantum-system-one.component.card-l-retina.ts=1706190248046.png/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1056px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/other/ul/cms/0c/98/ibm-quantum-system-one.component.card-l.ts=1706190248046.png/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card/image"></dds-image-item>
#     <dds-image-item media="(min-width: 672px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/other/ul/cms/0c/98/ibm-quantum-system-one.component.card-m-retina.ts=1706190248046.png/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card/image"></dds-image-item>
#     <dds-image-item media="(min-width: 672px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/other/ul/cms/0c/98/ibm-quantum-system-one.component.card-m.ts=1706190248046.png/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card/image"></dds-image-item>
#     <dds-image-item media="(min-width: 481px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/other/ul/cms/0c/98/ibm-quantum-system-one.component.card-s-retina.ts=1706190248046.png/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card/image"></dds-image-item>
#     <dds-image-item media="(min-width: 481px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/other/ul/cms/0c/98/ibm-quantum-system-one.component.card-s.ts=1706190248046.png/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card/image"></dds-image-item>
#     <dds-image-item media="(max-width: 480px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/other/ul/cms/0c/98/ibm-quantum-system-one.component.card-xs-retina.ts=1706190248046.png/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card/image"></dds-image-item>
#     <dds-image-item media="(max-width: 480px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/other/ul/cms/0c/98/ibm-quantum-system-one.component.card-xs.ts=1706190248046.png/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card/image"></dds-image-item>
#
#
#
#
#         </dds-image>
#
#
#
#
#
#
#
#
#         <dds-card-eyebrow slot="eyebrow" aria-hidden="true" class="bx--card__eyebrow">
#             IBM Research
#         </dds-card-eyebrow>
#         <dds-card-heading role="heading" aria-level="3" slot="heading" class="bx--card__heading">
#             See the latest technology developed by IBM scientists and design thinkers
#         </dds-card-heading>
#
#         <dds-card-cta-footer icon-placement="right" cta-type="local" href="https://research.ibm.com/?lnk=hpUSAp" slot="footer" aria-hidden="true" target="_self" class="bx--card__footer-icon-size">
#
#
#
#
#
#
#
#         </dds-card-cta-footer>
#     </dds-card-group-item>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <dds-card-group-item href="https://skillsbuild.org/?lnk=hpusap" target="_blank" pictogram-placement="top" cta-type="external">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <dds-image id="image--61986206" alt="Portrait of tech worker in front of giant server" slot="image" default-src="/content/dam/connectedassets-adobe-cms/worldwide-content/stock-assets/getty/image/photography/fe/64/universitychile0013846.component.card-xl.ts=1706190248137.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1937905391/image">
#
#
#
#
#     <dds-image-item media="(min-width: 1312px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/stock-assets/getty/image/photography/fe/64/universitychile0013846.component.card-xl-retina.ts=1706190248137.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1937905391/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1312px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/stock-assets/getty/image/photography/fe/64/universitychile0013846.component.card-xl.ts=1706190248137.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1937905391/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1056px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/stock-assets/getty/image/photography/fe/64/universitychile0013846.component.card-l-retina.ts=1706190248137.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1937905391/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1056px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/stock-assets/getty/image/photography/fe/64/universitychile0013846.component.card-l.ts=1706190248137.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1937905391/image"></dds-image-item>
#     <dds-image-item media="(min-width: 672px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/stock-assets/getty/image/photography/fe/64/universitychile0013846.component.card-m-retina.ts=1706190248137.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1937905391/image"></dds-image-item>
#     <dds-image-item media="(min-width: 672px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/stock-assets/getty/image/photography/fe/64/universitychile0013846.component.card-m.ts=1706190248137.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1937905391/image"></dds-image-item>
#     <dds-image-item media="(min-width: 481px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/stock-assets/getty/image/photography/fe/64/universitychile0013846.component.card-s-retina.ts=1706190248137.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1937905391/image"></dds-image-item>
#     <dds-image-item media="(min-width: 481px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/stock-assets/getty/image/photography/fe/64/universitychile0013846.component.card-s.ts=1706190248137.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1937905391/image"></dds-image-item>
#     <dds-image-item media="(max-width: 480px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/stock-assets/getty/image/photography/fe/64/universitychile0013846.component.card-xs-retina.ts=1706190248137.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1937905391/image"></dds-image-item>
#     <dds-image-item media="(max-width: 480px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/stock-assets/getty/image/photography/fe/64/universitychile0013846.component.card-xs.ts=1706190248137.jpg/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1937905391/image"></dds-image-item>
#
#
#
#
#         </dds-image>
#
#
#
#
#
#
#
#
#         <dds-card-eyebrow slot="eyebrow" aria-hidden="true" class="bx--card__eyebrow">
#             Training and skills
#         </dds-card-eyebrow>
#         <dds-card-heading role="heading" aria-level="3" slot="heading" class="bx--card__heading">
#             Power your future in tech with job skills, courses and credentials—for free
#         </dds-card-heading>
#
#         <dds-card-cta-footer icon-placement="right" cta-type="external" href="https://skillsbuild.org/?lnk=hpusap" slot="footer" aria-hidden="true" target="_blank" class="bx--card__footer-icon-size">
#
#
#
#
#
#
#
#         </dds-card-cta-footer>
#     </dds-card-group-item>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <dds-card-group-item href="1_qwhqg8r8" target="_self" pictogram-placement="top" cta-type="video" video-name="Watch IBM’s Darío Gil explain what AI will mean for business and society">
#
#
#
#
#         <dds-card-eyebrow slot="eyebrow" aria-hidden="true" class="bx--card__eyebrow">
#             Preview AI Academy
#         </dds-card-eyebrow>
#
#
#         <dds-card-cta-footer icon-placement="right" cta-type="video" href="1_qwhqg8r8" slot="footer" aria-hidden="true" class="bx--card__footer-icon-size">
#
#
#
#
#
#
#
#         </dds-card-cta-footer>
#     </dds-card-group-item>
#
#
#
#
#
#
#
#
#
#                 </dds-card-group>
#
#
#
#
#
#
#
#
#
#
#
#
#         </dds-content-block-cards>
#     </dds-video-cta-container>
#
#
# </div>
#
#
#     </div>
#
# </dds-table-of-contents>
# </div>
# <div class="footer">
#
#
#
#
#     <dds-footer-container data-cmp-is="footer" data-autoid="dds--footer" class="cmp-footer" data-children-count="0" size="tall"></dds-footer-container>
#
#
# </div>
#
#
#     </div>
#
# </div>
#
#
# <dds-lightbox-video-player-container></dds-lightbox-video-player-container>
#
#
#
# <script src="/etc.clientlibs/adobe-cms/clientlibs/clientlib-idlBundle.min.ACSHASH23cc0b9b9a73c9dd94381f29bf133f8a.js"></script>
#
#
#
#
#
#     <script src="/etc.clientlibs/adobe-cms/clientlibs/clientlib-target-antiflicker.min.ACSHASH36a1efb28e947b5873f4a28c2cf9d5eb.js"></script>
# <script src="/etc.clientlibs/adobe-cms/clientlibs/clientlib-idlWebComponents.min.ACSHASHaa58d161067036934162c981c49c78ef.js"></script>
# <script src="/etc.clientlibs/adobe-cms/clientlibs/clientlib-idlStyles.min.ACSHASH897814ade1034ba3448bfb2b0b09fde1.js"></script>
#
#
#
# <script src="https://www.ibm.com/common/digitaladvisor/cm-app/latest/cm-app.min.js" defer async></script>
#
#
#
#
#
#
#
#
#
#
#
# <script type="text/javascript"  src="/Yg6r5/1b_HH/8MNO6P/8Uty/rakiczkLhp/M35adQZpAw/TAohKAsO/E3k"></script><link rel="stylesheet" type="text/css"  href="/_sec/cp_challenge/sec-4-1.css">
#                                         <script  src="/_sec/cp_challenge/sec-cpt-4-1.js" async defer></script>
#                                         <div id="sec-overlay" style="display:none;">
#                                         <div id="sec-container">
#                                         </div>
#                                       </div></body>
# </html>

# %% [markdown]
# Create a soup object using the class BeautifulSoup

# %%
soup = BeautifulSoup(data,"html5lib")  # create a soup object using the variable 'data'

# %% [markdown]
# Scrape all links

# %%
for link in soup.find_all('a'):  # in html anchor/link is represented by the tag <a>
    print(link.get('href'))
# Out:
# https://www.ibm.com/cloud?lnk=hpUSbt1

# %% [markdown]
# Scrape  all images

# %%
for link in soup.find_all('img'):# in html image is represented by the tag <img>
    print(link.get('src'))

# %% [markdown]
# ## Scrape data from html tables

# %%
#The below url contains a html table with data about colors and color codes.

# %%
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/HTMLColorCodes.html"

# %% [markdown]
# Before proceeding to scrape a web site, you need to examine the contents, and the way data is organized on the website. Open the above url in your browser and check how many rows and columns are there in the color table.

# %%
# get the contents of the webpage in text format and store in a variable called data
data  = requests.get(url).text

# %%
soup = BeautifulSoup(data,"html5lib")

# %%
#find a html table in the web page
table = soup.find('table') # in html table is represented by the tag <table>

# %%
#Get all rows from the table
for row in table.find_all('tr'): # in html table row is represented by the tag <tr>
    # Get all columns in each row.
    cols = row.find_all('td') # in html a column is represented by the tag <td>
    color_name = cols[2].getText() # store the value in column 3 as color_name
    color_code = cols[3].getText() # store the value in column 4 as color_code
    print("{}--->{}".format(color_name,color_code))
# Out:
# Color Name--->Hex Code#RRGGBB
# lightsalmon--->#FFA07A
# salmon--->#FA8072
# darksalmon--->#E9967A
# lightcoral--->#F08080
# coral--->#FF7F50
# tomato--->#FF6347
# orangered--->#FF4500
# gold--->#FFD700
# orange--->#FFA500
# darkorange--->#FF8C00
# lightyellow--->#FFFFE0
# lemonchiffon--->#FFFACD
# papayawhip--->#FFEFD5
# moccasin--->#FFE4B5
# peachpuff--->#FFDAB9
# palegoldenrod--->#EEE8AA
# khaki--->#F0E68C
# darkkhaki--->#BDB76B
# yellow--->#FFFF00
# lawngreen--->#7CFC00
# chartreuse--->#7FFF00
# limegreen--->#32CD32
# lime--->#00FF00
# forestgreen--->#228B22
# green--->#008000
# powderblue--->#B0E0E6
# lightblue--->#ADD8E6
# lightskyblue--->#87CEFA
# skyblue--->#87CEEB
# deepskyblue--->#00BFFF
# lightsteelblue--->#B0C4DE
# dodgerblue--->#1E90FF

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2020-10-17  | 0.1  | Ramesh Sannareddy  |  Created initial version of the lab |

# %% [markdown]
#  Copyright &copy; 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2022-01-01).
