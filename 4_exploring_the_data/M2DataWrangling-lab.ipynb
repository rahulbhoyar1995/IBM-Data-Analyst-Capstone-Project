# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Data Wrangling Lab**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# In this assignment you will be performing data wrangling.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Identify duplicate values in the dataset.
#
# -   Remove duplicate values from the dataset.
#
# -   Identify missing values in the dataset.
#
# -   Impute the missing values in the dataset.
#
# -   Normalize data in the dataset.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import pandas module.

# %%
import pandas as pd

# %% [markdown]
# Load the dataset into a dataframe.

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m1_survey_data.csv")

# %%
df.shape
# Out:
# (11552, 85)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11552 entries, 0 to 11551
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              11552 non-null  int64
#  1   MainBranch              11552 non-null  object
#  2   Hobbyist                11552 non-null  object
#  3   OpenSourcer             11552 non-null  object
#  4   OpenSource              11471 non-null  object
#  5   Employment              11552 non-null  object
#  6   Country                 11552 non-null  object
#  7   Student                 11499 non-null  object
#  8   EdLevel                 11436 non-null  object
#  9   UndergradMajor          10812 non-null  object
#  10  EduOther                11388 non-null  object
#  11  OrgSize                 11454 non-null  object
#  12  DevType                 11485 non-null  object
#  13  YearsCode               11543 non-null  object
# ...

# %% [markdown]
# ## Finding duplicates

# %% [markdown]
# In this section you will identify duplicate values in the dataset.

# %% [markdown]
#  Find how many duplicate rows exist in the dataframe.

# %%
df.duplicated().value_counts()
# Out:
# False    11398
# True       154
# dtype: int64

# %%
duplicate_rows = df[df.duplicated()]
duplicate_rows
# Out:
#       Respondent                                         MainBranch Hobbyist  \
# 1168        2339                     I am a developer by profession      Yes
# 1169        2342                     I am a developer by profession      Yes
# 1170        2343                     I am a developer by profession      Yes
# 1171        2344                     I am a developer by profession      Yes
# 1172        2347                     I am a developer by profession      Yes
# ...          ...                                                ...      ...
# 2297        4674  I am not primarily a developer, but I write co...      Yes
# 2298        4675                     I am a developer by profession      Yes
# 2299        4676                     I am a developer by profession      Yes
# 2300        4677                     I am a developer by profession      Yes
# 2301        4679                     I am a developer by profession      Yes
#
# ...

# %%
number_of_duplicate_rows = len(duplicate_rows)

print("Number of duplicate rows in the DataFrame:", number_of_duplicate_rows)
# Out:
# Number of duplicate rows in the DataFrame: 154

# %% [markdown]
# ## Removing duplicates

# %% [markdown]
# Remove the duplicate rows from the dataframe.

# %%
print("Shape of dataframe before removing the duplicates :",df.shape)
# Out:
# Shape of dataframe before removing the duplicates : (11552, 85)

# %%
df = df.drop_duplicates()

# %% [markdown]
# Verify if duplicates were actually dropped.

# %%
# Print the shape of the DataFrame before and after removing duplicates
print("Shape of DataFrame after removing duplicates:", df.shape)
# Out:
# Shape of DataFrame after removing duplicates: (11398, 85)

# %% [markdown]
# You can see here that, before removing duplicates we had 11552 records, but after removing it we have 11398 records. 154 duplicate rows have been dropped.

# %% [markdown]
# ## Finding Missing values

# %% [markdown]
# Find the missing values for all columns.

# %%
missing_values = df.isnull().sum()

# Display the count of missing values for each column
print("Missing values for each column:")
print(missing_values)
# Out:
# Missing values for each column:
# Respondent        0
# MainBranch        0
# Hobbyist          0
# OpenSourcer       0
# OpenSource       81
#                ...
# Sexuality       542
# Ethnicity       675
# Dependents      140
# SurveyLength     19
# SurveyEase       14
# Length: 85, dtype: int64

# %% [markdown]
# Visualise the missing values.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df is your DataFrame
missing_values = df.isnull().sum()

# Sort the missing values in descending order
sorted_missing_values = missing_values.sort_values(ascending=False)

# Plotting sorted missing values using seaborn (horizontal bar chart)
plt.figure(figsize=(10, 6))
sns.barplot(x=sorted_missing_values.values, y=sorted_missing_values.index, hue=sorted_missing_values.index, palette='viridis', legend=False)
plt.title('Missing Values in Each Column')
plt.xlabel('Number of Missing Values')
plt.ylabel('Columns')
plt.show()

# %% [markdown]
# Find out how many rows are missing in the column 'WorkLoc'

# %%
print("Total missing values in 'WorkLoc' column is :",df["WorkLoc"].isnull().sum())
# Out:
# Total missing values in 'WorkLoc' column is : 32

# %% [markdown]
# ## Imputing missing values

# %% [markdown]
# Find the  value counts for the column WorkLoc.

# %%
# Assuming df is your DataFrame
workloc_value_counts = df['WorkLoc'].value_counts(dropna=False)

# Display the value counts, including missing values
print("Value counts for the column 'WorkLoc':")
print(workloc_value_counts)
# Out:
# Value counts for the column 'WorkLoc':
# Office                                            6806
# Home                                              3589
# Other place, such as a coworking space or cafe     971
# NaN                                                 32
# Name: WorkLoc, dtype: int64

# %% [markdown]
# Identify the value that is most frequent (majority) in the WorkLoc column.

# %%
most_frequent_workloc = df['WorkLoc'].mode()
most_frequent_workloc
# Out:
# 0    Office
# Name: WorkLoc, dtype: object

# %%
# Assuming df is your DataFrame
most_frequent_workloc = df['WorkLoc'].mode().iloc[0]

print("The most frequent value in the 'WorkLoc' column is:", most_frequent_workloc)
# Out:
# The most frequent value in the 'WorkLoc' column is: Office

# %% [markdown]
# Impute (replace) all the empty rows in the column WorkLoc with the value that you have identified as majority.

# %%
df['WorkLoc'] = df['WorkLoc'].fillna(most_frequent_workloc)

# %% [markdown]
# After imputation there should ideally not be any empty rows in the WorkLoc column.

# %% [markdown]
# Verify if imputing was successful.

# %%
print("Value counts for the column 'WorkLoc' after imputation:")
print(df['WorkLoc'].value_counts(dropna=False))
# Out:
# Value counts for the column 'WorkLoc' after imputation:
# Office                                            6838
# Home                                              3589
# Other place, such as a coworking space or cafe     971
# Name: WorkLoc, dtype: int64

# %% [markdown]
# ## Normalizing data

# %% [markdown]
# There are two columns in the dataset that talk about compensation.
#
# One is "CompFreq". This column shows how often a developer is paid (Yearly, Monthly, Weekly).
#
# The other is "CompTotal". This column talks about how much the developer is paid per Year, Month, or Week depending upon his/her "CompFreq".
#
# This makes it difficult to compare the total compensation of the developers.
#
# In this section you will create a new column called 'NormalizedAnnualCompensation' which contains the 'Annual Compensation' irrespective of the 'CompFreq'.
#
# Once this column is ready, it makes comparison of salaries easy.

# %% [markdown]
# <hr>

# %% [markdown]
# List out the various categories in the column 'CompFreq'

# %%
df["CompFreq"].value_counts(dropna = False)
# Out:
# Yearly     6073
# Monthly    4788
# Weekly      331
# NaN         206
# Name: CompFreq, dtype: int64

# %% [markdown]
# Create a new column named 'NormalizedAnnualCompensation'. Use the hint given below if needed.

# %% [markdown]
# Double click to see the **Hint**.
#
# <!--
#
# Use the below logic to arrive at the values for the column NormalizedAnnualCompensation.
#
# If the CompFreq is Yearly then use the exising value in CompTotal
# If the CompFreq is Monthly then multiply the value in CompTotal with 12 (months in an year)
# If the CompFreq is Weekly then multiply the value in CompTotal with 52 (weeks in an year)
#
# -->

# %%
import pandas as pd

# Assuming df is your DataFrame
def normalised_annual_compensation(row):
    comp_total = row["CompTotal"]
    comp_freq = row["CompFreq"]

    if comp_freq == "Yearly":
        return comp_total
    elif comp_freq == "Monthly":
        return comp_total * 12
    elif comp_freq == "Weekly":
        return comp_total * 52
    else:
        return comp_total

df["NormalizedAnnualCompensation"] = df.apply(normalised_annual_compensation, axis=1)

# Display the DataFrame with the new column
print(df[["CompTotal", "CompFreq", "NormalizedAnnualCompensation"]])
# Out:
#        CompTotal CompFreq  NormalizedAnnualCompensation
# 0        61000.0   Yearly                       61000.0
# 1       138000.0   Yearly                      138000.0
# 2        90000.0   Yearly                       90000.0
# 3        29000.0  Monthly                      348000.0
# 4        90000.0   Yearly                       90000.0
# ...          ...      ...                           ...
# 11547   130000.0   Yearly                      130000.0
# 11548    74400.0   Yearly                       74400.0
# 11549   105000.0   Yearly                      105000.0
# 11550    80000.0   Yearly                       80000.0
# 11551        NaN      NaN                           NaN
#
# [11398 rows x 3 columns]

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
#  Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2022-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
